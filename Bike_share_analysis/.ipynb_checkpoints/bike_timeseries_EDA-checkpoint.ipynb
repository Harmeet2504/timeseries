# %% [markdown]
# # EDA of Time Series Data for Bike Rental
#
# Demands for bike rental is governed by a number of factors including but not restricted to weather conditions, holiday seasons etc. This notebook is for exploratory analysis of such factors for data obtained from Capital bikeshare system in Washington, DC between years 2011 and 2012.

# %%
#import modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Read and display data
data=pd.read_csv("dc_bike_share_train.csv", parse_dates=["datetime"])
data.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %% [markdown]
# It is a timeseries data with hourly information from 1st Jan, 2011 to 19th Dec, 2012

# %%
# Check dataframe dimension
data.shape
# Out:
# (10886, 12)

# %% [markdown]
# There are 10885 datapoints (+1 for header) and 12 columns/features

# %%
#Check null values and datatypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.7 KB

# %% [markdown]
# There are no null values, data is clean. The 12 columns are int/float type with one datetime type

# %%
#Overall statistics
data.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %% [markdown]
# Numeric features are in same scale and might not need pre-processing for training (depending on the model). The mean of registered bikes (155) is way higher than that of casual(36) riders implying there are more registered users.

# %% [markdown]
# ## Distribution of data

# %%
#Pairplot to view data distribution and identify correlation between features and between feature&target
sns.pairplot(data)
plt.savefig("figures/pairplot.png")

# %% [markdown]
# There are 4 categorical features (season, holiday, workingday, weather) and 6 numerical features of which temp, atemp, windspeed, humidity are normally distributed while casual and registered are skewed. Count is the target. temp and atemp are linearly correlated, registered shares high correlation with the target. Will check these in detail later through correlation heatmap. Let's check count of distinct values in the categorical variables.

# %%
data["season"].value_counts()
# Out:
# 4    2734
# 3    2733
# 2    2733
# 1    2686
# Name: season, dtype: int64

# %% [markdown]
# There are 4 seasons during the time period of the data (spring, summer, fall, winter)

# %%
data["holiday"].value_counts()
# Out:
# 0    10575
# 1      311
# Name: holiday, dtype: int64

# %% [markdown]
# Assuming 0 means no holiday and 1 means holiday, during the time period, there are less holidays

# %%
data["workingday"].value_counts()
# Out:
# 1    7412
# 0    3474
# Name: workingday, dtype: int64

# %% [markdown]
# During the time period, there are more working days as compared to weekend or holiday

# %%
data["weather"].value_counts()
# Out:
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: weather, dtype: int64

# %% [markdown]
# As per the data source, following weather conditions have been defined:
# 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 4: Heavy Rain + Ice Pallets + Thunderstorme values

# %% [markdown]
# ## Correlation heatmap
#
# Identify highly correlated features by computing pearson's correlation coefficient

# %%
#get correlations of each features in dataset
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(14,12))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True)
plt.savefig("figures/correlation_matrix")

# %% [markdown]
# If we are going to forecast count, then it is important to note that both registered and casual are highly correlated. And to avoid overfitting, one feature can be dropped. Since register has high correlation with count, so it is more likely to be a better predictor. Hence it can be retained. Also, it would make no sense to keep both temperature and average temperature for analysis as they have a very high correlation.

# %% [markdown]
# ## Seasonal influence on bike rent

# %%
# df = data.copy
season_data=data.groupby("season")["count"].sum()
legend = ["spring","summer", "fall", "winter"]
ax = season_data.plot(kind='bar', figsize=(8,5), color="cyan", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("Season wise count of bike rides", fontsize=20)
ax.set_ylabel("Sum of rides", fontsize=15)
ax.set_xlabel("Season", fontsize=15)
plt.tight_layout()
plt.savefig("figures/seasonalEffect.png")
plt.show();

# %% [markdown]
# Highest ride is in fall followed by in summer. Least ride is during spring. The trend for winter and spring seems strange given that weather conditions are more favorable in spring.

# %% [markdown]
# ## Implication of holiday

# %%
holiday_data=data.groupby("holiday")["count"].sum()
ax = holiday_data.plot(kind='bar', figsize=(5,4), color="cyan", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("Count of bike rides during holiday", fontsize=12)
ax.set_ylabel("Sum of rides", fontsize=15)
ax.set_xlabel("Holiday", fontsize=15)
plt.tight_layout()
plt.savefig("figures/holidayEffect.png")
plt.show();

# %% [markdown]
# The count of rides is definitely low on holidays vs non-holidays but it is to be noted that during the entire period, there are only 311 holidays as compared to 10,575 non-holidays. Hence, for a fair comparison, the percent difference should be computed.

# %% [markdown]
# ## Implication of working day

# %%
workday_data=data.groupby("workingday")["count"].sum()
ax = workday_data.plot(kind='bar', figsize=(5,4), color="cyan", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("Count of bike rides during workday", fontsize=12)
ax.set_ylabel("Sum of rides", fontsize=15)
ax.set_xlabel("Workday", fontsize=15)
plt.tight_layout()
plt.savefig("figures/workdayEffect.png")
plt.show();

# %% [markdown]
# There are more rides on working day vs weekends/holidays. but the same is true here as in the above case with holidays. However, here both holiday and weekend have been grouped as 0, so the value is comparatievely higher.

# %% [markdown]
# ## Feature engineering:
#
# Extract months, days,weekday name and hours from the datetime series using pandas. This will add more sense to analyze the data

# %%
# Extract months, days, hours, weekday name as new features
data["month"]=data["datetime"].dt.month
data["day"]=data["datetime"].dt.day
data["hour"]=data["datetime"].dt.hour
data["weekday"]=data["datetime"].dt.day_name()
data=data.set_index("datetime")
data
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
#                      humidity  windspeed  casual  registered  count  month  \
# datetime
# 2011-01-01 00:00:00        81     0.0000       3          13     16      1
# 2011-01-01 01:00:00        80     0.0000       8          32     40      1
# 2011-01-01 02:00:00        80     0.0000       5          27     32      1
# 2011-01-01 03:00:00        75     0.0000       3          10     13      1
# 2011-01-01 04:00:00        75     0.0000       0           1      1      1
# ...                       ...        ...     ...         ...    ...    ...
# 2012-12-19 19:00:00        50    26.0027       7         329    336     12
# 2012-12-19 20:00:00        57    15.0013      10         231    241     12
# 2012-12-19 21:00:00        61    15.0013       4         164    168     12
# 2012-12-19 22:00:00        61     6.0032      12         117    129     12
# 2012-12-19 23:00:00        66     8.9981       4          84     88     12
#
#                      day  hour    weekday
# datetime
# 2011-01-01 00:00:00    1     0   Saturday
# 2011-01-01 01:00:00    1     1   Saturday
# 2011-01-01 02:00:00    1     2   Saturday
# 2011-01-01 03:00:00    1     3   Saturday
# 2011-01-01 04:00:00    1     4   Saturday
# ...                  ...   ...        ...
# 2012-12-19 19:00:00   19    19  Wednesday
# 2012-12-19 20:00:00   19    20  Wednesday
# 2012-12-19 21:00:00   19    21  Wednesday
# 2012-12-19 22:00:00   19    22  Wednesday
# 2012-12-19 23:00:00   19    23  Wednesday
#
# [10886 rows x 15 columns]

# %% [markdown]
# The highest day seem to be 19. Let's check and confirm.

# %%
data["day"].max()
# Out:
# 19

# %% [markdown]
# The data is for 19th of every month for 2011-2012

# %% [markdown]
# ## Weather implications

# %%
w=sns.factorplot('month','count', hue='weather',data=data, ci=None, palette='husl')
plt.savefig("figures/weather.png");
# Out:
# /Users/harmeetkaur/opt/anaconda3/envs/insight/lib/python3.8/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# Clearly there are more rentals during clear(1) weather followed by misty/cloudy(2) followed by snowy/rainy weather(3). No one dares to ride during heavy rain, thunderstorm etc. as reflected by a singly data point (4)

# %% [markdown]
# ## Seasonality
#
# Seasonality refers to periodic fluctuations in time series data that happens at regular periods. While traditionally used to literally mean seasons (e.g. Spring, Summer, Autumn, Winter), it can occur during any time period, like hours, days, or weeks.

# %% [markdown]
# ### Seasonality in weather conditions and count of bike rides
#
# First group the data by time, and display distribution for each time point to visualize seasonality using box-plot

# %%
#Function to create boxplot:

def boxPlot(col_names, n, x, d):
    """
    Function to create boxplot
    Arguments: names of columns, number of subplots, column for x-axis, dataframe
    Outputs subplots of boxplot for every column 
    """
    fig, axes = plt.subplots(n, 1, figsize=(11, 18), sharex=True)
    for name, ax in zip(col_names, axes):
        sns.boxplot(data=d, x=x, y=name, ax=ax)
        ax.set_ylabel('Values')
        ax.set_title(name)
        # Remove the automatic x-axis label from all but the bottom subplot
        if ax != axes[-1]:
            ax.set_xlabel('')

# %% [markdown]
# ### 1. Monthly

# %%
#For monthly trend, it makes sense to use avg. temp i.e. "atemp"
col_names=["count", "atemp", "windspeed", "humidity"]
n = len(col_names)
d=data
x='month'
boxPlot(col_names, n, x, d)

# %% [markdown]
# Count of rides gradually increases during summer months, i.e. from May to June and July and gradually decreases. However there is slight decrease up until October.
# This trend is evident in the temperature/average temperature. While July is the hottest month, the count of bikes is almost equal during June and July.
# January has the least rides,followed by February. Its upper quartile is lower than February and December. This can be attributed to extreme temperature and holiday season.
# The median windspeed is almost constant during June to October, this could impact bike riding. May, September, October and December have the highest humidity.

# %% [markdown]
# ## 2. Daily (weekdays)

# %%
col_names=["count", "atemp", "windspeed", "humidity"]
n = len(col_names)
d=data
x='weekday'
boxPlot(col_names, n, x, d)

# %% [markdown]
# The dispersion of data is almost equal or slightly higher on weekends as compared to that of weekdays. However, on weekdays the median is high and there are more high outliers, suggesting more bike share.

# %% [markdown]
# ## 3. Hourly

# %%
col_names=["count", "temp", "windspeed", "humidity"]
n = len(col_names)
d=data
x='hour'
#Function call
boxPlot(col_names, n, x, d)

# %% [markdown]
# Bike share is high between 7am-8am and then gradually decreases and remains constant from 12-3pm and peaks again around 5pm-6pm. This coincides with regular office hours.The high outliers are presumably during working days.
# While temperature and average temperature gradually increases from 8am and then gradually decreases from 4pm, the change is marginal. Should this be correlated with spikes in bike share is not very clear. Similarly with hourly windspeed and humidity.

# %% [markdown]
# ## Stationarity
# A Time series (TS) is said to be stationary if its statistical properties such as mean, variance remain constant over time and an autocovariance that does not depend on time. Most of the TS models work on the assumption that the TS is stationary. Intuitively, we can say that if a TS has a particular behaviour over time, there is a very high probability that it will follow the same in the future.
#
# Using the Augmented Dickey Fuller test (adfuller()), from the statsmodels package to check for stationarity. The null hypothesis of the ADF test is that the time series is non-stationary. So, if the p-value of the test is less than the significance level (0.05) then you reject the null hypothesis and infer that the time series is indeed stationary.
#
# So, in our case, if P Value > 0.05 we go ahead with finding the order of differencing.

# %%
#Check for stationarity in relevant features
from statsmodels.tsa.stattools import adfuller
from numpy import log
col=data[["count", "atemp", "registered", "casual"]]
for i in col:
    print(i)
    result = adfuller(data[i].dropna())
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
# Out:
# count
# ADF Statistic: -6.419976
# p-value: 0.000000
# atemp
# ADF Statistic: -4.366516
# p-value: 0.000340
# registered
# ADF Statistic: -7.475670
# p-value: 0.000000
# casual
# ADF Statistic: -10.383743
# p-value: 0.000000

# %% [markdown]
# Since p-value is less than the significance level (0.05), we reject the null hypothesis. Hence, data is stationary. So, no differencing is required.

# %% [markdown]
# ## Visualization for blog:
# Breaking out important visualizations from subplots(above) that provide significant observations

# %%
#Monthly trend
ax = sns.boxplot(x="month", y="count", data=data)
plt.xlabel("month", fontsize=15)
plt.ylabel("count", fontsize=15)
plt.title("Monthly Trend in Count of Rides")
plt.tight_layout()
plt.savefig("figures/monthlyTrend.png")

# %%
#Weekly trend
ax = sns.boxplot(x="weekday", y="count", data=data)
plt.xlabel("weekday", fontsize=15)
plt.ylabel("count", fontsize=15)
plt.title("Weekly Trend in Count of Rides")
plt.tight_layout()
plt.savefig("figures/weeklyTrend.png")

# %%
#Hourly trend
ax = sns.boxplot(x="hour", y="count", data=data)
plt.xlabel("hour", fontsize=15)
plt.ylabel("count", fontsize=15)
plt.title("Hourly Trend in Count of Rides")
plt.tight_layout()
plt.savefig("figures/hourlyTrend.png")
